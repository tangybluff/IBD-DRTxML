# %%
import pandas as pd

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

from ydata_synthetic.synthesizers.regular import RegularSynthesizer
from ydata_synthetic.synthesizers import ModelParameters, TrainParameters

# %% [markdown]
# Read the original data and have it preprocessed

# %%
data_path = "./data/df_clean.pkl"
data = pd.read_pickle(data_path)

# %%
fecha_inicio_far = data["fecha_inicio_far"]
fecha_diag = data["fecha_diag"]

data.drop(columns=["fecha_inicio_far", "fecha_diag"], inplace=True)

# %%
cat_cols = list(data.select_dtypes(include="category").columns)
num_cols = list(data.select_dtypes(include='number').columns)

sort_columns = ['ppio_activo',
'sexo',
'familia_eii',
'loc_ec',
'comp_ec',
'exten_cu',
'tipo_eii',
'preianal',
'ada_previo',
'ifx_previo',
'uste_previo',
'vedo_previo',
'tofa_previo',
'certol_previo',
'golim_previo',
'cx_previa_eii',
'tabaco',
'meis_espondiloartropatías',
'meis_uveitis',
'meis_eritema_nodoso',
'meis_pioderma_gangrenoso',
'meis_colangitis_esclerosanteprimaria',
'meis_estomatitis_aftosa',
'meis_SdSweet',
'meis_psoriasis',
'meis_hidrosiadenitis',
'meis_vasculitis',
'meis_vitiligo',
'meis_osteoporosis',
'meis_fenom_tromboembolico',
'edad_inicio_far',
'edad_diag',
'cort_12m_previo',
'diabetes',
'asma',
'vih',
'migrana',
'calprotectina',
'lab_velocidad_sed_globular',
'lab_sodio',
'lab_aspartato_transaminasa',
'lab_glucosa',
'lab_proteinas_totales',
'lab_urea',
'lab_potasio',
'lab_alanina_transaminasa',
'lab_acido_folico',
'lab_vitamina_b12',
'lab_ferritina',
'lab_creatinina',
'lab_proteina_c_reactiva',
'lab_trigliceridos',
'lab_colesterol',
'lab_volumen_plaquetario_medio',
'lab_plaquetas_recuento',
'lab_basofilos_porcentaje',
'lab_eosinofilos_porcentaje',
'lab_linfocitos_porcentaje',
'lab_neutrofilos_porcentaje',
'lab_basofilos_recuento',
'lab_eosinofilos_recuento',
'lab_monocitos_recuento',
'lab_linfocitos_recuento',
'lab_neutrofilos_recuento',
'lab_leucocitos_recuento',
'lab_dispersion_hematies_volumen',
'lab_hemoglobina_corpuscular_media',
'lab_volumen_corpuscular_medio',
'lab_hematocrito',
'lab_hematies_recuento',
'lab_bilirrubina_total',
'lab_fosfatasa_alcalina',
'lab_alfa_1_glicoproteina_acida',
'res_clin_26', # Target
'res_clin_52', # Target
'rem_clin_52', # Target
'res_clin_104', # Target
'rem_clin_104',] # Target

processed_data = data[sort_columns].copy()

# %%
train_data = processed_data.copy()

# %% [markdown]
# Se imputan los NA's

# %%
train_numeric = train_data[num_cols]

# Crear un imputador iterativo con un modelo de regresión lineal
imputer = IterativeImputer(estimator=LinearRegression(), max_iter=10, random_state=0)

# Imputar valores faltantes
imputed_data = imputer.fit_transform(train_numeric)

df_num_imputed = pd.DataFrame(imputed_data, columns=train_numeric.columns)
# Out:
# /home/juanluisgonzalez/FPS_proyects/EII/.venv/lib64/python3.9/site-packages/sklearn/impute/_iterative.py:800: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
df_num_imputed.index = train_data.index

# %%
train_data[num_cols] = df_num_imputed[num_cols].round(3)
train_data
# Out:
#         ppio_activo sexo familia_eii loc_ec comp_ec exten_cu tipo_eii  \
# ID
# HVM1    USTEKINUMAB    H           0      2       1        0       EC
# HVM2    VEDOLIZUMAB    M           0      0       0        3       CU
# HVM3    USTEKINUMAB    H           0      1       3        0       EC
# HVM4    VEDOLIZUMAB    H           2      2       2        0       EC
# HVM5    USTEKINUMAB    H           2      2       2        0       EC
# ...             ...  ...         ...    ...     ...      ...      ...
# HVM224  USTEKINUMAB    H           0      0       0        2       CU
# HVM225  USTEKINUMAB    H           0      0       0        3       CU
# HVM226  USTEKINUMAB    H           0      3       3        0       EC
# HVM227  USTEKINUMAB    H           0      1       1        0       EC
# HVM228  USTEKINUMAB    H           0      2       1        0       EC
#
#        preianal ada_previo ifx_previo  ... lab_hematocrito  \
# ID                                     ...
# HVM1          1          1          1  ...          40.331
# HVM2          0          1          1  ...           0.300
# HVM3          1          0          1  ...          40.377
# HVM4          1          1          1  ...          39.478
# HVM5          1          1          1  ...          39.547
# ...         ...        ...        ...  ...             ...
# HVM224        0          0          1  ...          38.000
# HVM225        0          1          1  ...          39.800
# HVM226        1          1          1  ...          45.000
# HVM227        1          1          1  ...          44.300
# HVM228        1          0          1  ...          40.500
#
#        lab_hematies_recuento lab_bilirrubina_total lab_fosfatasa_alcalina  \
# ID
# HVM1                   4.664                 0.515                 73.155
# HVM2                   3.350                 0.570                 68.000
# HVM3                   4.658                 0.505                 73.475
# HVM4                   4.641                 0.507                 69.827
# HVM5                   4.632                 0.492                 70.308
# ...                      ...                   ...                    ...
# HVM224                 4.040                 0.280                100.000
# HVM225                 5.270                 0.380                 89.000
# HVM226                 5.150                 0.320                 61.000
# HVM227                 4.800                 0.710                 80.000
# HVM228                 4.030                 0.390                110.000
#
#        lab_alfa_1_glicoproteina_acida res_clin_26 res_clin_52 rem_clin_52  \
# ID
# HVM1                           70.065           1           1           1
# HVM2                         -271.879           1           1           0
# HVM3                           71.545           0           1           1
# HVM4                           67.415           1           1           0
# HVM5                           69.635           0           0           0
# ...                               ...         ...         ...         ...
# HVM224                        166.300           1           1           1
# HVM225                        313.800           0           0           0
# HVM226                         97.500           1           1           0
# HVM227                         98.000           1           1           1
# HVM228                        166.782           1           1           1
#
#        res_clin_104 rem_clin_104
# ID
# HVM1              1            1
# HVM2              0            0
# HVM3              1            1
# HVM4            NaN          NaN
# HVM5              0            0
# ...             ...          ...
# HVM224            0            0
# HVM225            0            0
# HVM226            0            0
# HVM227          NaN          NaN
# HVM228          NaN          NaN
#
# [228 rows x 78 columns]

# %%
num_rows_with_na = train_data.isna().any(axis=1).sum()
print(f'Número de filas con al menos un valor nulo: {num_rows_with_na}')

# Remove rows with any NA
train_data_clean = train_data.dropna()
print(train_data_clean.shape)

index_nas = train_data[train_data.isna().any(axis=1)].index
fecha_diag = fecha_diag.drop(index_nas)
fecha_inicio_far = fecha_inicio_far.drop(index_nas)

train_data_clean = train_data_clean.reset_index().drop(columns="ID")
fecha_diag = fecha_diag.reset_index().drop(columns="ID")
fecha_inicio_far = fecha_inicio_far.reset_index().drop(columns="ID")
# Out:
# Número de filas con al menos un valor nulo: 46
# (182, 78)

# %% [markdown]
# Conver dates to timestamp integer

# %%
train_data_clean["fecha_diag_timestamp"] = fecha_diag.astype(int) // 10**9
train_data_clean["fecha_inicio_far_timestamp"] = fecha_diag.astype(int) // 10**9

# %%
train_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 80 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ppio_activo                           182 non-null    category
#  1   sexo                                  182 non-null    category
#  2   familia_eii                           182 non-null    category
#  3   loc_ec                                182 non-null    category
#  4   comp_ec                               182 non-null    category
#  5   exten_cu                              182 non-null    category
#  6   tipo_eii                              182 non-null    category
#  7   preianal                              182 non-null    category
#  8   ada_previo                            182 non-null    category
#  9   ifx_previo                            182 non-null    category
#  10  uste_previo                           182 non-null    category
#  11  vedo_previo                           182 non-null    category
#  12  tofa_previo                           182 non-null    category
#  13  certol_previo                         182 non-null    category
#  14  golim_previo                          182 non-null    category
#  15  cx_previa_eii                         182 non-null    category
#  16  tabaco                                182 non-null    category
#  17  meis_espondiloartropatías             182 non-null    category
#  18  meis_uveitis                          182 non-null    category
#  19  meis_eritema_nodoso                   182 non-null    category
#  20  meis_pioderma_gangrenoso              182 non-null    category
#  21  meis_colangitis_esclerosanteprimaria  182 non-null    category
#  22  meis_estomatitis_aftosa               182 non-null    category
#  23  meis_SdSweet                          182 non-null    category
#  24  meis_psoriasis                        182 non-null    category
#  25  meis_hidrosiadenitis                  182 non-null    category
#  26  meis_vasculitis                       182 non-null    category
#  27  meis_vitiligo                         182 non-null    category
#  28  meis_osteoporosis                     182 non-null    category
#  29  meis_fenom_tromboembolico             182 non-null    category
#  30  edad_inicio_far                       182 non-null    float64
#  31  edad_diag                             182 non-null    float64
#  32  cort_12m_previo                       182 non-null    category
#  33  diabetes                              182 non-null    category
#  34  asma                                  182 non-null    category
#  35  vih                                   182 non-null    category
#  36  migrana                               182 non-null    category
#  37  calprotectina                         182 non-null    float64
#  38  lab_velocidad_sed_globular            182 non-null    float64
#  39  lab_sodio                             182 non-null    float64
#  40  lab_aspartato_transaminasa            182 non-null    float64
#  41  lab_glucosa                           182 non-null    float64
#  42  lab_proteinas_totales                 182 non-null    float64
#  43  lab_urea                              182 non-null    float64
#  44  lab_potasio                           182 non-null    float64
#  45  lab_alanina_transaminasa              182 non-null    float64
#  46  lab_acido_folico                      182 non-null    float64
#  47  lab_vitamina_b12                      182 non-null    float64
#  48  lab_ferritina                         182 non-null    float64
#  49  lab_creatinina                        182 non-null    float64
#  50  lab_proteina_c_reactiva               182 non-null    float64
#  51  lab_trigliceridos                     182 non-null    float64
#  52  lab_colesterol                        182 non-null    float64
#  53  lab_volumen_plaquetario_medio         182 non-null    float64
#  54  lab_plaquetas_recuento                182 non-null    float64
#  55  lab_basofilos_porcentaje              182 non-null    float64
#  56  lab_eosinofilos_porcentaje            182 non-null    float64
#  57  lab_linfocitos_porcentaje             182 non-null    float64
#  58  lab_neutrofilos_porcentaje            182 non-null    float64
#  59  lab_basofilos_recuento                182 non-null    float64
#  60  lab_eosinofilos_recuento              182 non-null    float64
#  61  lab_monocitos_recuento                182 non-null    float64
#  62  lab_linfocitos_recuento               182 non-null    float64
#  63  lab_neutrofilos_recuento              182 non-null    float64
#  64  lab_leucocitos_recuento               182 non-null    float64
#  65  lab_dispersion_hematies_volumen       182 non-null    float64
#  66  lab_hemoglobina_corpuscular_media     182 non-null    float64
#  67  lab_volumen_corpuscular_medio         182 non-null    float64
#  68  lab_hematocrito                       182 non-null    float64
#  69  lab_hematies_recuento                 182 non-null    float64
#  70  lab_bilirrubina_total                 182 non-null    float64
#  71  lab_fosfatasa_alcalina                182 non-null    float64
#  72  lab_alfa_1_glicoproteina_acida        182 non-null    float64
#  73  res_clin_26                           182 non-null    category
#  74  res_clin_52                           182 non-null    category
#  75  rem_clin_52                           182 non-null    category
#  76  res_clin_104                          182 non-null    category
#  77  rem_clin_104                          182 non-null    category
#  78  fecha_diag_timestamp                  182 non-null    int64
#  79  fecha_inicio_far_timestamp            182 non-null    int64
# dtypes: category(40), float64(38), int64(2)
# memory usage: 66.6 KB

# %% [markdown]
# Generate synthetic data

# %%
print(train_data_clean[cat_cols].dtypes)
# Out:
# ppio_activo                             category
# sexo                                    category
# familia_eii                             category
# loc_ec                                  category
# comp_ec                                 category
# exten_cu                                category
# tipo_eii                                category
# preianal                                category
# ada_previo                              category
# ifx_previo                              category
# uste_previo                             category
# vedo_previo                             category
# tofa_previo                             category
# certol_previo                           category
# golim_previo                            category
# cx_previa_eii                           category
# tabaco                                  category
# meis_espondiloartropatías               category
# meis_uveitis                            category
# meis_eritema_nodoso                     category
# meis_pioderma_gangrenoso                category
# meis_colangitis_esclerosanteprimaria    category
# meis_estomatitis_aftosa                 category
# meis_SdSweet                            category
# meis_psoriasis                          category
# meis_hidrosiadenitis                    category
# meis_vasculitis                         category
# meis_vitiligo                           category
# meis_osteoporosis                       category
# meis_fenom_tromboembolico               category
# res_clin_26                             category
# res_clin_52                             category
# rem_clin_52                             category
# res_clin_104                            category
# rem_clin_104                            category
# cort_12m_previo                         category
# diabetes                                category
# asma                                    category
# vih                                     category
# migrana                                 category
# dtype: object

# %%
cat_cols = list(train_data_clean.select_dtypes(include="category").columns)
num_cols = list(train_data_clean.select_dtypes(include='number').columns)

train_data_clean[cat_cols] = train_data_clean[cat_cols].astype(str)


synth = RegularSynthesizer(modelname='fast')
synth.fit(data=train_data_clean, num_cols=num_cols, cat_cols=cat_cols)
# Out:
# Hyperparameter search: 100%|██████████| 8/8 [00:04<00:00,  1.68it/s]

# %% [markdown]
# Generate 500 rows

# %%
synth_data = synth.sample(1000)
synth_data
# Out:
#      ppio_activo sexo familia_eii loc_ec comp_ec exten_cu tipo_eii preianal  \
# 0    VEDOLIZUMAB    M           0      0       0        3       CU        0
# 1    VEDOLIZUMAB    M           0      0       0        3       CU        0
# 2    USTEKINUMAB    M           0      0       0        2       CU        0
# 3    VEDOLIZUMAB    H           0      0       0        2       CU        0
# 4    VEDOLIZUMAB    M           0      0       0        3       CU        0
# ..           ...  ...         ...    ...     ...      ...      ...      ...
# 995  USTEKINUMAB    H           0      1       2        0       EC        1
# 996  USTEKINUMAB    M           0      1       2        0       EC        0
# 997  VEDOLIZUMAB    M           0      1       1        0       EC        0
# 998  USTEKINUMAB    M           0      1       2        0       EC        0
# 999  USTEKINUMAB    H           0      1       2        0       EC        0
#
#     ada_previo ifx_previo  ... lab_bilirrubina_total lab_fosfatasa_alcalina  \
# 0            0          0  ...              0.213100              92.988628
# 1            0          1  ...              0.411969              66.385975
# 2            1          1  ...              0.743418              74.631522
# 3            1          0  ...              0.010493             108.100160
# 4            1          0  ...              0.199082             111.490397
# ..         ...        ...  ...                   ...                    ...
# 995          1          1  ...              0.097636              84.406909
# 996          0          1  ...              0.385416             108.313646
# 997          0          1  ...              0.386420              90.888795
# 998          0          0  ...              0.542376              74.548122
# 999          1          1  ...              0.145593              51.942475
#
#     lab_alfa_1_glicoproteina_acida res_clin_26 res_clin_52 rem_clin_52  \
# 0                       200.044479           0           0           0
# 1                        62.947759           0           1           0
# 2                        79.462422           1           1           1
# 3                         4.718868           1           1           1
# 4                       117.877358           1           1           0
# ..                             ...         ...         ...         ...
# 995                     118.203019           1           1           0
# 996                     159.650650           1           1           1
# 997                     116.663942           1           1           1
# 998                     113.437789           1           0           0
# 999                     107.406870           1           0           0
#
#     res_clin_104 rem_clin_104 fecha_diag_timestamp fecha_inicio_far_timestamp
# 0              0            1           1639200521                 1638760985
# 1              1            0            938467017                  935997132
# 2              1            1            716299462                  715087827
# 3              1            1           1345650586                 1346474958
# 4              1            1           1556366959                 1558013081
# ..           ...          ...                  ...                        ...
# 995            0            0           1459116296                 1459767296
# 996            1            1           1147481808                 1146268328
# 997            0            0           1154422508                 1154167093
# 998            1            1           1466192254                 1466798441
# 999            0            0           1660274892                 1659875583
#
# [1000 rows x 80 columns]

# %% [markdown]
# Set timestamps as dates again

# %%
synth_data['fecha_inicio_far'] = pd.to_datetime(synth_data['fecha_inicio_far_timestamp'], unit='s')
synth_data.drop(columns=["fecha_inicio_far_timestamp"], inplace=True)
synth_data['fecha_diag'] = pd.to_datetime(synth_data['fecha_diag_timestamp'], unit='s')
synth_data.drop(columns=["fecha_diag_timestamp"], inplace=True)

# %%
# Assuming 'fech_diag' and 'fecha_inicio_far_timestamp' are the date columns
mask = synth_data['fecha_diag'] >= synth_data['fecha_inicio_far']

# Count the number of rows that do not satisfy the condition
num_rows_not_satisfying_condition = (~mask).sum()

# Display the count of rows not satisfying the condition
print(f"Number of rows not satisfying the condition: {num_rows_not_satisfying_condition}")

# Drop rows that do not satisfy the condition
synth_data = synth_data[mask]
# Out:
# Number of rows not satisfying the condition: 494

# %%
list_ids =[f"HUVM_{i}" for i in range(1, len(synth_data) + 1)]
synth_data= synth_data.copy()
synth_data.loc[:, 'ID'] = list_ids

synth_data = synth_data[sort_columns].copy()

synth_data.head()
# Out:
#    ppio_activo sexo familia_eii loc_ec comp_ec exten_cu tipo_eii preianal  \
# 0  VEDOLIZUMAB    M           0      0       0        3       CU        0
# 1  VEDOLIZUMAB    M           0      0       0        3       CU        0
# 2  USTEKINUMAB    M           0      0       0        2       CU        0
# 5  VEDOLIZUMAB    H           0      0       0        2       CU        1
# 7  VEDOLIZUMAB    H           0      0       0        2       CU        0
#
#   ada_previo ifx_previo  ... lab_hematocrito lab_hematies_recuento  \
# 0          0          0  ...       45.973943              4.542077
# 1          0          1  ...       43.618085              5.000956
# 2          1          1  ...       44.327137              5.118912
# 5          1          1  ...       38.643741              4.180835
# 7          1          0  ...       55.185318              5.355321
#
#   lab_bilirrubina_total lab_fosfatasa_alcalina lab_alfa_1_glicoproteina_acida  \
# 0              0.213100              92.988628                     200.044479
# 1              0.411969              66.385975                      62.947759
# 2              0.743418              74.631522                      79.462422
# 5              0.374859             109.105071                     159.625742
# 7              0.786882              62.261477                     193.597199
#
#   res_clin_26 res_clin_52 rem_clin_52 res_clin_104 rem_clin_104
# 0           0           0           0            0            1
# 1           0           1           0            1            0
# 2           1           1           1            1            1
# 5           1           1           1            1            1
# 7           0           0           1            0            0
#
# [5 rows x 78 columns]

# %% [markdown]
# save as csv

# %%
synth_data.to_csv('data/synthetic_data.csv', index=False)
