# %% [markdown]
# # Read and cleaning
#
# In this notebook, an Excel file will be read and set as the description of the dataset. Additionally, the variables and rows will be prepared for use in the models

# %% [markdown]
# ## 0. Load Dependences

# %%
import pandas as pd
from tabulate import tabulate
import pickle

# %% [markdown]
# ## 1. Read Excel

# %%
excel_df = pd.read_excel("./data/Base_uste_vedo_anonimizada.xlsx", index_col="ID")
display(excel_df.head())
# Out:
#      fecha_INCIO_fac  MES  YEAR      FECHA fecha_diag           pa sex  \
# ID
# HVM1      2020-09-30    9  2020 2020-09-30 2007-01-01  USTEKINUMAB   H
# HVM2      2016-05-27    5  2016 2016-05-27 2000-01-01  VEDOLIZUMAB   M
# HVM3      2020-12-02   12  2020 2020-12-02 2008-12-02  USTEKINUMAB   H
# HVM4      2021-05-20    5  2021 2021-05-20 2009-10-01  VEDOLIZUMAB   H
# HVM5      2018-04-26    4  2018 2018-04-26 2009-10-01  USTEKINUMAB   H
#
#       0_ninguno; 1_1º grado; 2_2º grado  \
# ID
# HVM1                                0.0
# HVM2                                0.0
# HVM3                                0.0
# HVM4                                2.0
# HVM5                                2.0
#
#       1_ileal; 2_colónica; 3_ileocolónica; 4_ileocolónica + superior; 5_ileal + superior  \
# ID
# HVM1                                                  2
# HVM2                                                  0
# HVM3                                                  1
# HVM4                                                  2
# HVM5                                                  2
#
#       1_inflamatorip;2_estenosante;3_fistulizante  ...  Hematíes (recuento)  \
# ID                                                 ...
# HVM1                                            1  ...                  NaN
# HVM2                                            0  ...                 3.35
# HVM3                                            3  ...                  NaN
# HVM4                                            2  ...                  NaN
# HVM5                                            2  ...                  NaN
#
#      Albúmina  Bilirrubina total  Tiempo de protrombina (ratio)  \
# ID
# HVM1      NaN                NaN                            NaN
# HVM2      NaN               0.57                            NaN
# HVM3      NaN                NaN                            NaN
# HVM4      NaN                NaN                            NaN
# HVM5      NaN                NaN                            NaN
#
#       Tiroxina (libre)  Tirotropina  Bilirrubina directa  \
# ID
# HVM1               NaN          NaN                  NaN
# HVM2              1.04         0.15                  0.2
# HVM3               NaN          NaN                  NaN
# HVM4               NaN          NaN                  NaN
# HVM5               NaN          NaN                  NaN
#
#       Lactato deshidrogenasa  Fosfatasa alcalina  alfa-1-Glicoproteína ácida
# ID
# HVM1                     NaN                 NaN                         NaN
# HVM2                     NaN                68.0                         NaN
# HVM3                     NaN                 NaN                         NaN
# HVM4                     NaN                 NaN                         NaN
# HVM5                     NaN                 NaN                         NaN
#
# [5 rows x 111 columns]

# %% [markdown]
# Unuseful or columns with reapled info will be deleted.

# %%
cols2drop = ["MES",
"YEAR",
"FECHA",
"Naïve",
"BIO_previo",
"TNF_previo",
"Cx_ concurrente",
"MEIS",
"MEIS: 1_espondiloartropatías; 2_uveitis, epiescleritis; 3_eritema_nodoso; 4_pioderma gangrenoso; 5_colangitis esclerosanteprimaria; 6_estomatitis aftosa; 7_SdSweet; 8_psoriasis; 9_hidrosiadenitis supuratina; 10_vasculitis; 11_vitiligo; 12_ osteoporosis; 13_fenom_tromboembolico",
"MEIS_TOTALES",
"CPF_52",
"PCR_52",
"Fecha_nac",
"Años_enfermedad",
"PREDNISONA",
"DEFLAZACORT",
"TRIAMCINOLONA",
"DEXAMETASONA",
"METILPREDNISOLONA",]

# drop the previos variables
print(print(excel_df.shape))
excel_df = excel_df.drop(columns=cols2drop)
print(excel_df.shape)
# Out:
# (228, 111)
# None
# (228, 92)

# %% [markdown]
# ## 2. Rename variables

# %%
excel_df.columns = excel_df.columns.str.strip()
# Some columns has a special invisible character insead a space
excel_df.columns = excel_df.columns.str.replace('\u00a0', ' ')

map_names = {#"old_name" : "new_name"
             "fecha_INCIO_fac": "fecha_inicio_far",
             "fecha_diag": "fecha_diag",
             "pa": "ppio_activo",
             "sex": "sexo",
             "0_ninguno; 1_1º grado; 2_2º grado": "familia_eii",
             "1_ileal; 2_colónica; 3_ileocolónica; 4_ileocolónica + superior; 5_ileal + superior": "loc_ec",
             "1_inflamatorip;2_estenosante;3_fistulizante": "comp_ec",
             "1_proctitis;2_colitis izquierda; 3_pancolitis": "exten_cu",
             "Tipo EII": "tipo_eii",
             "Perianal": "preianal",
             "ADA_previo": "ada_previo",
             "IFX_previo": "ifx_previo",
             "USTE_previo": "uste_previo",
             "VEDO_previo": "vedo_previo",
             "TOFA_previo": "tofa_previo",
             "Certol_previo": "certol_previo",
             "Golim_previo": "golim_previo",
             "Cx_previa_EII": "cx_previa_eii",
             "Tabaco": "tabaco",
             "MEIS: 1_espondiloartropatías": "meis_espondiloartropatías",
             "2_uveitis": "meis_uveitis",
             "3_eritema_nodoso": "meis_eritema_nodoso",
             "4_pioderma gangrenoso": "meis_pioderma_gangrenoso",
             "5_colangitis esclerosanteprimaria": "meis_colangitis_esclerosanteprimaria",
             "6_estomatitis aftosa": "meis_estomatitis_aftosa",
             "7_SdSweet": "meis_SdSweet",
             "8_psoriasis": "meis_psoriasis",
             "9_hidrosiadenitis": "meis_hidrosiadenitis",
             "10_vasculitis": "meis_vasculitis",
             "11_vitiligo": "meis_vitiligo",
             "12_ osteoporosis": "meis_osteoporosis",
             "13_fenom_tromboembolico": "meis_fenom_tromboembolico",
             "Resp_clin_06": "res_clin_26",
             "Resp_clin_50": "res_clin_52",
             "Rem_clin_50": "rem_clin_52",
             "Resp_clin_10": "res_clin_104",
             "Rem_clin_10": "rem_clin_104",
             "Edad_inicio_F": "edad_inicio_far",
             "Edad_diag": "edad_diag",
             "Corticoides 12 meses previo a inicio tratamiento": "cort_12m_previo",
             "DIABETES": "diabetes",
             "ASMA": "asma",
             "VIH": "vih",
             "MIGRAÑA": "migrana",
             "Calprotectina (heces)": "calprotectina",
             "Velocidad de sedimentación globular": "lab_velocidad_sed_globular",
             "Sodio": "lab_sodio",
             "Aspartato transaminasa": "lab_aspartato_transaminasa",
             "Glucosa": "lab_glucosa",
             "Proteínas totales": "lab_proteinas_totales",
             "Urea": "lab_urea",
             "Potasio": "lab_potasio",
             "Alanina transaminasa": "lab_alanina_transaminasa",
             "Tiempo de protrombina normalizado (INR)": "lab_tiempo_protrombina_inr",
             "Ácido fólico": "lab_acido_folico",
             "Vitamina B12": "lab_vitamina_b12",
             "Transferrina": "lab_transferrina",
             "Ferritina": "lab_ferritina",
             "Creatinina": "lab_creatinina",
             "Proteína C reactiva": "lab_proteina_c_reactiva",
             "Triglicéridos": "lab_trigliceridos",
             "Colesterol": "lab_colesterol",
             "Tiempo de protrombina (porcentaje)": "lab_tiempo_protrombina_porcentaje",
             "Tiempo de tromboplastina parcial activada (segundos)": "lab_tiempo_ttpa_segundos",
             "Tiempo de protrombina (segundos)": "lab_tiempo_protrombina_segundos",
             "Tiempo de tromboplastina parcial activada (ratio)": "lab_ttpa_ratio",
             "Volumen plaquetario medio": "lab_volumen_plaquetario_medio",
             "Plaquetas (recuento)": "lab_plaquetas_recuento",
             "Basófilos (porcentaje)": "lab_basofilos_porcentaje",
             "Eosinófilos (porcentaje)": "lab_eosinofilos_porcentaje",
             "Linfocitos (porcentaje)": "lab_linfocitos_porcentaje",
             "Neutrófilos (porcentaje)": "lab_neutrofilos_porcentaje",
             "Basófilos (recuento)": "lab_basofilos_recuento",
             "Eosinófilos (recuento)": "lab_eosinofilos_recuento",
             "Monocitos (recuento)": "lab_monocitos_recuento",
             "Linfocitos (recuento)": "lab_linfocitos_recuento",
             "Neutrófilos (recuento)": "lab_neutrofilos_recuento",
             "Leucocitos (recuento)": "lab_leucocitos_recuento",
             "Dispersión de hematíes (volumen)": "lab_dispersion_hematies_volumen",
             "Hemoglobina corpuscular media": "lab_hemoglobina_corpuscular_media",
             "Volumen corpuscular medio": "lab_volumen_corpuscular_medio",
             "Hematocrito": "lab_hematocrito",
             "Hematíes (recuento)": "lab_hematies_recuento",
             "Albúmina": "lab_albumina",
             "Bilirrubina total": "lab_bilirrubina_total",
             "Tiempo de protrombina (ratio)": "lab_tiempo_protrombina_ratio",
             "Tiroxina (libre)": "lab_tiroxina_libre",
             "Tirotropina": "lab_tirotropina",
             "Bilirrubina directa": "lab_bilirrubina_directa",
             "Lactato deshidrogenasa": "lab_lactato_deshidrogenasa",
             "Fosfatasa alcalina": "lab_fosfatasa_alcalina",
             "alfa-1-Glicoproteína ácida": "lab_alfa_1_glicoproteina_acida"
             }

excel_df.rename(columns=map_names, inplace=True)

# %% [markdown]
# ## 3. Check NA in variables and clean
# Variables with over 50% missing values will be excluded.

# %%
# Calculate the percentage of missing values per column
null_percentage = (excel_df.isnull().sum() / len(excel_df)) * 100

# Create a new DataFrame with the missing values percentage information
df_nulls = pd.DataFrame({'Variable': null_percentage.index, '% of missing values': null_percentage.values})

# Filter the columns with more than 50% missing values
df_nulls_filtered = df_nulls[df_nulls['% of missing values'] > 50]

print("\nVariables with more than 50% missing values:")
print(df_nulls_filtered)
# Out:
# Variables with more than 50% missing values:
#                              Variable  % of missing values
# 53         lab_tiempo_protrombina_inr            62.719298
# 56                   lab_transferrina            73.245614
# 62  lab_tiempo_protrombina_porcentaje            64.035088
# 63           lab_tiempo_ttpa_segundos            89.473684
# 64    lab_tiempo_protrombina_segundos            63.596491
# 65                     lab_ttpa_ratio            64.473684
# 83                       lab_albumina            75.000000
# 85       lab_tiempo_protrombina_ratio            95.175439
# 86                 lab_tiroxina_libre            84.210526
# 87                    lab_tirotropina            70.614035
# 88            lab_bilirrubina_directa            94.736842
# 89         lab_lactato_deshidrogenasa            69.298246

# %% [markdown]
# Let's drop these variables

# %%
print(excel_df.shape)
excel_df.drop(columns=df_nulls_filtered["Variable"], inplace=True)
print(excel_df.shape)
# Out:
# (228, 92)
# (228, 80)

# %% [markdown]
# ## 4. Check and remove rows

# %% [markdown]
# Let's verify if there are any records with more than 50% of missing values in their variables.

# %%
# isna() function to check for missing values and sum them per row
rows_with_na = excel_df.isna().sum(axis=1)

# Compare with 50% of the columns' length
rows_with_more_than_50_percent_na = rows_with_na > 0.5 * len(excel_df.columns)

# Select rows that meet this condition
rows_with_more_than_50_percent_na_df = excel_df[rows_with_more_than_50_percent_na]

# Use display to show the DataFrame
print(rows_with_more_than_50_percent_na_df)
# Out:
# Empty DataFrame
# Columns: [fecha_inicio_far, fecha_diag, ppio_activo, sexo, familia_eii, loc_ec, comp_ec, exten_cu, tipo_eii, preianal, ada_previo, ifx_previo, uste_previo, vedo_previo, tofa_previo, certol_previo, golim_previo, cx_previa_eii, tabaco, meis_espondiloartropatías, meis_uveitis, meis_eritema_nodoso, meis_pioderma_gangrenoso, meis_colangitis_esclerosanteprimaria, meis_estomatitis_aftosa, meis_SdSweet, meis_psoriasis, meis_hidrosiadenitis, meis_vasculitis, meis_vitiligo, meis_osteoporosis, meis_fenom_tromboembolico, res_clin_26, res_clin_52, rem_clin_52, res_clin_104, rem_clin_104, edad_inicio_far, edad_diag, cort_12m_previo, diabetes, asma, vih, migrana, calprotectina, lab_velocidad_sed_globular, lab_sodio, lab_aspartato_transaminasa, lab_glucosa, lab_proteinas_totales, lab_urea, lab_potasio, lab_alanina_transaminasa, lab_acido_folico, lab_vitamina_b12, lab_ferritina, lab_creatinina, lab_proteina_c_reactiva, lab_trigliceridos, lab_colesterol, lab_volumen_plaquetario_medio, lab_plaquetas_recuento, lab_basofilos_porcentaje, lab_eosinofilos_porcentaje, lab_linfocitos_porcentaje, lab_neutrofilos_porcentaje, lab_basofilos_recuento, lab_eosinofilos_recuento, lab_monocitos_recuento, lab_linfocitos_recuento, lab_neutrofilos_recuento, lab_leucocitos_recuento, lab_dispersion_hematies_volumen, lab_hemoglobina_corpuscular_media, lab_volumen_corpuscular_medio, lab_hematocrito, lab_hematies_recuento, lab_bilirrubina_total, lab_fosfatasa_alcalina, lab_alfa_1_glicoproteina_acida]
# Index: []
#
# [0 rows x 80 columns]

# %% [markdown]
# There're no rows with more than 50% of missing values.

# %% [markdown]
# ## 5. Check datatype
# An exploration of the data types will be performed to ensure their correctness.

# %%
data_types_table = []

for col, dtype in excel_df.dtypes.items():
    data_types_table.append([col, str(dtype)])

# Print as table
print(tabulate(data_types_table, headers=["Variable", "Dtype"]))
# Out:
# Variable                              Dtype
# ------------------------------------  --------------
# fecha_inicio_far                      datetime64[ns]
# fecha_diag                            datetime64[ns]
# ppio_activo                           object
# sexo                                  object
# familia_eii                           float64
# loc_ec                                int64
# comp_ec                               int64
# exten_cu                              int64
# tipo_eii                              object
# preianal                              int64
# ada_previo                            int64
# ifx_previo                            int64
# uste_previo                           int64
# vedo_previo                           int64
# tofa_previo                           int64
# certol_previo                         int64
# golim_previo                          int64
# cx_previa_eii                         int64
# tabaco                                float64
# meis_espondiloartropatías             int64
# meis_uveitis                          int64
# meis_eritema_nodoso                   int64
# meis_pioderma_gangrenoso              int64
# meis_colangitis_esclerosanteprimaria  int64
# meis_estomatitis_aftosa               int64
# meis_SdSweet                          int64
# meis_psoriasis                        int64
# meis_hidrosiadenitis                  int64
# meis_vasculitis                       int64
# meis_vitiligo                         int64
# meis_osteoporosis                     int64
# meis_fenom_tromboembolico             int64
# res_clin_26                           int64
# res_clin_52                           object
# rem_clin_52                           object
# res_clin_104                          object
# rem_clin_104                          object
# edad_inicio_far                       int64
# edad_diag                             int64
# cort_12m_previo                       int64
# diabetes                              object
# asma                                  object
# vih                                   object
# migrana                               object
# calprotectina                         float64
# lab_velocidad_sed_globular            float64
# lab_sodio                             float64
# lab_aspartato_transaminasa            float64
# lab_glucosa                           float64
# lab_proteinas_totales                 float64
# lab_urea                              float64
# lab_potasio                           float64
# lab_alanina_transaminasa              float64
# lab_acido_folico                      float64
# lab_vitamina_b12                      float64
# lab_ferritina                         float64
# lab_creatinina                        float64
# lab_proteina_c_reactiva               float64
# lab_trigliceridos                     float64
# lab_colesterol                        float64
# lab_volumen_plaquetario_medio         float64
# lab_plaquetas_recuento                float64
# lab_basofilos_porcentaje              float64
# lab_eosinofilos_porcentaje            float64
# lab_linfocitos_porcentaje             float64
# lab_neutrofilos_porcentaje            float64
# lab_basofilos_recuento                float64
# lab_eosinofilos_recuento              float64
# lab_monocitos_recuento                float64
# lab_linfocitos_recuento               float64
# lab_neutrofilos_recuento              float64
# lab_leucocitos_recuento               float64
# lab_dispersion_hematies_volumen       float64
# lab_hemoglobina_corpuscular_media     float64
# lab_volumen_corpuscular_medio         float64
# lab_hematocrito                       float64
# lab_hematies_recuento                 float64
# lab_bilirrubina_total                 float64
# lab_fosfatasa_alcalina                float64
# lab_alfa_1_glicoproteina_acida        float64

# %% [markdown]
# Some variable types are incorrect. These variables will be accurately encoded.

# %%
dtypes_dict = {"ppio_activo": "category",
               "sexo": "category",
               "familia_eii": "category",
               "loc_ec": "category",
               "comp_ec": "category",
               "exten_cu": "category",
               "tipo_eii": "category",
               "preianal": "category",
               "ada_previo": "category",
               "ifx_previo": "category",
               "uste_previo": "category",
               "vedo_previo": "category",
               "tofa_previo": "category",
               "certol_previo": "category",
               "golim_previo": "category",
               "cx_previa_eii": "category",
               "tabaco": "category",
               "meis_espondiloartropatías": "category",
               "meis_uveitis": "category",
               "meis_eritema_nodoso": "category",
               "meis_pioderma_gangrenoso": "category",
               "meis_colangitis_esclerosanteprimaria": "category",
               "meis_estomatitis_aftosa": "category",
               "meis_SdSweet": "category",
               "meis_psoriasis": "category",
               "meis_hidrosiadenitis": "category",
               "meis_vasculitis": "category",
               "meis_vitiligo": "category",
               "meis_osteoporosis": "category",
               "meis_fenom_tromboembolico": "category",
               "res_clin_26": "category",
               "res_clin_52": "category",
               "rem_clin_52": "category",
               "res_clin_104": "category",
               "rem_clin_104": "category",
               "cort_12m_previo": "category",
               "diabetes": "category",
               "asma": "category",
               "vih": "category",
               "migrana": "category",
               "lab_aspartato_transaminasa": "Int64",
               "lab_fosfatasa_alcalina": "Int64"

}

#Convert dtypes
excel_df = excel_df.astype(dtypes_dict)

# Get new dtypes
data_types_table = []

for col, dtype in excel_df.dtypes.items():
    data_types_table.append([col, str(dtype)])

# Print as table
print(tabulate(data_types_table, headers=["Variable", "Dtype"]))
# Out:
# Variable                              Dtype
# ------------------------------------  --------------
# fecha_inicio_far                      datetime64[ns]
# fecha_diag                            datetime64[ns]
# ppio_activo                           category
# sexo                                  category
# familia_eii                           category
# loc_ec                                category
# comp_ec                               category
# exten_cu                              category
# tipo_eii                              category
# preianal                              category
# ada_previo                            category
# ifx_previo                            category
# uste_previo                           category
# vedo_previo                           category
# tofa_previo                           category
# certol_previo                         category
# golim_previo                          category
# cx_previa_eii                         category
# tabaco                                category
# meis_espondiloartropatías             category
# meis_uveitis                          category
# meis_eritema_nodoso                   category
# meis_pioderma_gangrenoso              category
# meis_colangitis_esclerosanteprimaria  category
# meis_estomatitis_aftosa               category
# meis_SdSweet                          category
# meis_psoriasis                        category
# meis_hidrosiadenitis                  category
# meis_vasculitis                       category
# meis_vitiligo                         category
# meis_osteoporosis                     category
# meis_fenom_tromboembolico             category
# res_clin_26                           category
# res_clin_52                           category
# rem_clin_52                           category
# res_clin_104                          category
# rem_clin_104                          category
# edad_inicio_far                       int64
# edad_diag                             int64
# cort_12m_previo                       category
# diabetes                              category
# asma                                  category
# vih                                   category
# migrana                               category
# calprotectina                         float64
# lab_velocidad_sed_globular            float64
# lab_sodio                             float64
# lab_aspartato_transaminasa            Int64
# lab_glucosa                           float64
# lab_proteinas_totales                 float64
# lab_urea                              float64
# lab_potasio                           float64
# lab_alanina_transaminasa              float64
# lab_acido_folico                      float64
# lab_vitamina_b12                      float64
# lab_ferritina                         float64
# lab_creatinina                        float64
# lab_proteina_c_reactiva               float64
# lab_trigliceridos                     float64
# lab_colesterol                        float64
# lab_volumen_plaquetario_medio         float64
# lab_plaquetas_recuento                float64
# lab_basofilos_porcentaje              float64
# lab_eosinofilos_porcentaje            float64
# lab_linfocitos_porcentaje             float64
# lab_neutrofilos_porcentaje            float64
# lab_basofilos_recuento                float64
# lab_eosinofilos_recuento              float64
# lab_monocitos_recuento                float64
# lab_linfocitos_recuento               float64
# lab_neutrofilos_recuento              float64
# lab_leucocitos_recuento               float64
# lab_dispersion_hematies_volumen       float64
# lab_hemoglobina_corpuscular_media     float64
# lab_volumen_corpuscular_medio         float64
# lab_hematocrito                       float64
# lab_hematies_recuento                 float64
# lab_bilirrubina_total                 float64
# lab_fosfatasa_alcalina                Int64
# lab_alfa_1_glicoproteina_acida        float64

# %%
excel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 228 entries, HVM1 to HVM228
# Data columns (total 80 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   fecha_inicio_far                      228 non-null    datetime64[ns]
#  1   fecha_diag                            228 non-null    datetime64[ns]
#  2   ppio_activo                           228 non-null    category
#  3   sexo                                  228 non-null    category
#  4   familia_eii                           223 non-null    category
#  5   loc_ec                                228 non-null    category
#  6   comp_ec                               228 non-null    category
#  7   exten_cu                              228 non-null    category
#  8   tipo_eii                              228 non-null    category
#  9   preianal                              228 non-null    category
#  10  ada_previo                            228 non-null    category
#  11  ifx_previo                            228 non-null    category
#  12  uste_previo                           228 non-null    category
#  13  vedo_previo                           228 non-null    category
#  14  tofa_previo                           228 non-null    category
#  15  certol_previo                         228 non-null    category
#  16  golim_previo                          228 non-null    category
#  17  cx_previa_eii                         228 non-null    category
#  18  tabaco                                226 non-null    category
#  19  meis_espondiloartropatías             228 non-null    category
#  20  meis_uveitis                          228 non-null    category
#  21  meis_eritema_nodoso                   228 non-null    category
#  22  meis_pioderma_gangrenoso              228 non-null    category
#  23  meis_colangitis_esclerosanteprimaria  228 non-null    category
#  24  meis_estomatitis_aftosa               228 non-null    category
#  25  meis_SdSweet                          228 non-null    category
#  26  meis_psoriasis                        228 non-null    category
#  27  meis_hidrosiadenitis                  228 non-null    category
#  28  meis_vasculitis                       228 non-null    category
#  29  meis_vitiligo                         228 non-null    category
#  30  meis_osteoporosis                     228 non-null    category
#  31  meis_fenom_tromboembolico             228 non-null    category
#  32  res_clin_26                           228 non-null    category
#  33  res_clin_52                           228 non-null    category
#  34  rem_clin_52                           228 non-null    category
#  35  res_clin_104                          190 non-null    category
#  36  rem_clin_104                          190 non-null    category
#  37  edad_inicio_far                       228 non-null    int64
#  38  edad_diag                             228 non-null    int64
#  39  cort_12m_previo                       228 non-null    category
#  40  diabetes                              227 non-null    category
#  41  asma                                  227 non-null    category
#  42  vih                                   227 non-null    category
#  43  migrana                               227 non-null    category
#  44  calprotectina                         143 non-null    float64
#  45  lab_velocidad_sed_globular            137 non-null    float64
#  46  lab_sodio                             147 non-null    float64
#  47  lab_aspartato_transaminasa            146 non-null    Int64
#  48  lab_glucosa                           147 non-null    float64
#  49  lab_proteinas_totales                 146 non-null    float64
#  50  lab_urea                              144 non-null    float64
#  51  lab_potasio                           147 non-null    float64
#  52  lab_alanina_transaminasa              147 non-null    float64
#  53  lab_acido_folico                      134 non-null    float64
#  54  lab_vitamina_b12                      140 non-null    float64
#  55  lab_ferritina                         137 non-null    float64
#  56  lab_creatinina                        147 non-null    float64
#  57  lab_proteina_c_reactiva               142 non-null    float64
#  58  lab_trigliceridos                     122 non-null    float64
#  59  lab_colesterol                        117 non-null    float64
#  60  lab_volumen_plaquetario_medio         148 non-null    float64
#  61  lab_plaquetas_recuento                149 non-null    float64
#  62  lab_basofilos_porcentaje              150 non-null    float64
#  63  lab_eosinofilos_porcentaje            150 non-null    float64
#  64  lab_linfocitos_porcentaje             149 non-null    float64
#  65  lab_neutrofilos_porcentaje            149 non-null    float64
#  66  lab_basofilos_recuento                150 non-null    float64
#  67  lab_eosinofilos_recuento              150 non-null    float64
#  68  lab_monocitos_recuento                149 non-null    float64
#  69  lab_linfocitos_recuento               149 non-null    float64
#  70  lab_neutrofilos_recuento              149 non-null    float64
#  71  lab_leucocitos_recuento               148 non-null    float64
#  72  lab_dispersion_hematies_volumen       148 non-null    float64
#  73  lab_hemoglobina_corpuscular_media     149 non-null    float64
#  74  lab_volumen_corpuscular_medio         149 non-null    float64
#  75  lab_hematocrito                       149 non-null    float64
#  76  lab_hematies_recuento                 149 non-null    float64
#  77  lab_bilirrubina_total                 135 non-null    float64
#  78  lab_fosfatasa_alcalina                133 non-null    Int64
#  79  lab_alfa_1_glicoproteina_acida        124 non-null    float64
# dtypes: Int64(2), category(40), datetime64[ns](2), float64(34), int64(2)
# memory usage: 87.5+ KB

# %% [markdown]
# ## 6. Analyze dataframe

# %% [markdown]
# Numeric variables analysis

# %%
display(excel_df.describe().transpose())
# Out:
#                                    count                           mean  \
# fecha_inicio_far                     228  2019-12-16 01:28:25.263158016
# fecha_diag                           228  2008-07-28 09:34:44.210526208
# edad_inicio_far                    228.0                      45.526316
# edad_diag                          228.0                      34.530702
# calprotectina                      143.0                     584.395804
# lab_velocidad_sed_globular         137.0                      13.912409
# lab_sodio                          147.0                     140.591837
# lab_aspartato_transaminasa         146.0                      19.821918
# lab_glucosa                        147.0                      91.891156
# lab_proteinas_totales              146.0                       7.071233
# lab_urea                           144.0                      32.013889
# lab_potasio                        147.0                       4.437415
# lab_alanina_transaminasa           147.0                      19.863946
# lab_acido_folico                   134.0                       6.402239
# lab_vitamina_b12                   140.0                     393.607143
# lab_ferritina                      137.0                     131.138686
# lab_creatinina                     147.0                       0.826259
# lab_proteina_c_reactiva            142.0                       12.24507
# lab_trigliceridos                  122.0                     130.565574
# lab_colesterol                     117.0                     174.735043
# lab_volumen_plaquetario_medio      148.0                      10.736486
# lab_plaquetas_recuento             149.0                     291.020134
# lab_basofilos_porcentaje           150.0                          0.662
# lab_eosinofilos_porcentaje         150.0                       2.239333
# lab_linfocitos_porcentaje          149.0                      28.383893
# lab_neutrofilos_porcentaje         149.0                      60.680537
# lab_basofilos_recuento             150.0                       0.053733
# lab_eosinofilos_recuento           150.0                       0.182067
# lab_monocitos_recuento             149.0                       0.675906
# lab_linfocitos_recuento            149.0                       2.351208
# lab_neutrofilos_recuento           149.0                       5.416107
# lab_leucocitos_recuento            148.0                       8.639054
# lab_dispersion_hematies_volumen    148.0                      13.899324
# lab_hemoglobina_corpuscular_media  149.0                      29.652349
# lab_volumen_corpuscular_medio      149.0                      91.988591
# lab_hematocrito                    149.0                      41.974497
# lab_hematies_recuento              149.0                       4.679262
# lab_bilirrubina_total              135.0                       0.486889
# lab_fosfatasa_alcalina             133.0                       79.37594
# lab_alfa_1_glicoproteina_acida     124.0                      90.599194
#
#                                                    min                  25%  \
# fecha_inicio_far                   2015-01-01 00:00:00  2018-11-20 18:00:00
# fecha_diag                         1985-01-01 00:00:00  2002-04-11 00:00:00
# edad_inicio_far                                   12.0                 35.0
# edad_diag                                          4.0                 22.0
# calprotectina                                      0.0                 51.1
# lab_velocidad_sed_globular                         0.0                  6.0
# lab_sodio                                        133.0                138.0
# lab_aspartato_transaminasa                         0.0                 15.0
# lab_glucosa                                       60.0                 80.0
# lab_proteinas_totales                              5.1                  6.8
# lab_urea                                           8.0                 24.0
# lab_potasio                                        0.0                  4.2
# lab_alanina_transaminasa                           0.0                 12.0
# lab_acido_folico                                   0.0                  3.0
# lab_vitamina_b12                                   0.0               268.75
# lab_ferritina                                      0.0                 34.4
# lab_creatinina                                    0.44                  0.7
# lab_proteina_c_reactiva                            0.0                  1.5
# lab_trigliceridos                                  0.0                 77.0
# lab_colesterol                                     0.0                147.0
# lab_volumen_plaquetario_medio                      8.4                 10.0
# lab_plaquetas_recuento                            70.0                231.0
# lab_basofilos_porcentaje                           0.0                  0.4
# lab_eosinofilos_porcentaje                         0.0                 0.95
# lab_linfocitos_porcentaje                          6.1                 22.3
# lab_neutrofilos_porcentaje                        38.0                 52.9
# lab_basofilos_recuento                             0.0                 0.04
# lab_eosinofilos_recuento                           0.0               0.0825
# lab_monocitos_recuento                            0.11                 0.52
# lab_linfocitos_recuento                           0.58                 1.67
# lab_neutrofilos_recuento                          1.77                 3.71
# lab_leucocitos_recuento                            3.7                 6.83
# lab_dispersion_hematies_volumen                   11.8                 12.8
# lab_hemoglobina_corpuscular_media                 20.9                 28.3
# lab_volumen_corpuscular_medio                     67.4                 88.7
# lab_hematocrito                                    0.3                 40.5
# lab_hematies_recuento                             3.06                 4.33
# lab_bilirrubina_total                              0.0                 0.27
# lab_fosfatasa_alcalina                            32.0                 61.0
# lab_alfa_1_glicoproteina_acida                    41.8                 72.4
#
#                                                    50%                  75%  \
# fecha_inicio_far                   2020-04-15 00:00:00  2021-02-21 00:00:00
# fecha_diag                         2009-08-21 00:00:00  2015-01-01 00:00:00
# edad_inicio_far                                   43.0                 57.0
# edad_diag                                         30.0                 46.0
# calprotectina                                    147.8               485.45
# lab_velocidad_sed_globular                         9.0                 18.0
# lab_sodio                                        141.0                143.0
# lab_aspartato_transaminasa                        18.0                21.75
# lab_glucosa                                       89.0                101.0
# lab_proteinas_totales                             7.15                7.475
# lab_urea                                          30.0                 37.0
# lab_potasio                                        4.5                  4.7
# lab_alanina_transaminasa                          15.0                 24.0
# lab_acido_folico                                   4.9                6.775
# lab_vitamina_b12                                 353.0                467.5
# lab_ferritina                                     71.5                153.1
# lab_creatinina                                    0.78                  0.9
# lab_proteina_c_reactiva                           3.25                9.625
# lab_trigliceridos                                119.0               163.75
# lab_colesterol                                   171.0                203.0
# lab_volumen_plaquetario_medio                    10.65                 11.4
# lab_plaquetas_recuento                           270.0                336.0
# lab_basofilos_porcentaje                           0.7                  0.8
# lab_eosinofilos_porcentaje                         1.9                  3.1
# lab_linfocitos_porcentaje                         29.3                 36.3
# lab_neutrofilos_porcentaje                        58.9                 66.5
# lab_basofilos_recuento                            0.05                 0.07
# lab_eosinofilos_recuento                          0.16               0.2675
# lab_monocitos_recuento                            0.63                 0.77
# lab_linfocitos_recuento                            2.2                 2.77
# lab_neutrofilos_recuento                          4.86                 6.23
# lab_leucocitos_recuento                          8.145              10.0825
# lab_dispersion_hematies_volumen                   13.3                 14.3
# lab_hemoglobina_corpuscular_media                 29.7                 31.2
# lab_volumen_corpuscular_medio                     92.3                 96.1
# lab_hematocrito                                   42.8                 45.5
# lab_hematies_recuento                             4.68                 4.99
# lab_bilirrubina_total                             0.39                0.615
# lab_fosfatasa_alcalina                            74.0                 89.0
# lab_alfa_1_glicoproteina_acida                    84.7              103.525
#
#                                                    max          std
# fecha_inicio_far                   2022-01-05 00:00:00          NaN
# fecha_diag                         2021-06-29 00:00:00          NaN
# edad_inicio_far                                   80.0     15.68591
# edad_diag                                         76.0    16.320143
# calprotectina                                   8349.9  1238.379849
# lab_velocidad_sed_globular                        66.0    11.768274
# lab_sodio                                        149.0     2.955735
# lab_aspartato_transaminasa                        54.0     8.489088
# lab_glucosa                                      178.0     17.28097
# lab_proteinas_totales                              8.1     0.549728
# lab_urea                                         102.0    14.296063
# lab_potasio                                        5.8     0.604233
# lab_alanina_transaminasa                          87.0    12.690542
# lab_acido_folico                                 103.0     9.330147
# lab_vitamina_b12                                1716.0   210.018317
# lab_ferritina                                   1513.5   189.933635
# lab_creatinina                                    2.45     0.265021
# lab_proteina_c_reactiva                          246.3    27.718848
# lab_trigliceridos                                490.0    72.846378
# lab_colesterol                                   345.0    50.179917
# lab_volumen_plaquetario_medio                     13.8     1.124928
# lab_plaquetas_recuento                           808.0    95.186905
# lab_basofilos_porcentaje                           1.5     0.303596
# lab_eosinofilos_porcentaje                         8.4     1.697329
# lab_linfocitos_porcentaje                         50.6     9.905773
# lab_neutrofilos_porcentaje                        91.5    11.021439
# lab_basofilos_recuento                            0.13     0.025291
# lab_eosinofilos_recuento                          0.62     0.136442
# lab_monocitos_recuento                            1.91     0.259537
# lab_linfocitos_recuento                           6.19     0.989402
# lab_neutrofilos_recuento                          18.3     2.618771
# lab_leucocitos_recuento                          21.43     2.871622
# lab_dispersion_hematies_volumen                   46.7     3.048798
# lab_hemoglobina_corpuscular_media                 36.7     2.555798
# lab_volumen_corpuscular_medio                    109.6     6.851647
# lab_hematocrito                                   52.0      7.29263
# lab_hematies_recuento                             5.93     0.530493
# lab_bilirrubina_total                             1.88     0.336952
# lab_fosfatasa_alcalina                           234.0    27.105742
# lab_alfa_1_glicoproteina_acida                   313.8    32.694013

# %% [markdown]
# **Data Analysis Summary**
#
# Dates:
# - The dataset comprises two date columns, namely `fecha_inicio_far` (indicating the start date) and `fecha_diag` (representing the diagnosis date). The time range for the start date extends from 2015 to 2022, while the diagnosis date spans from 1985 to the first half of 2022.
#
# Ages:
# - The average age at the start of treatment (`edad_inicio_far`) is around 45 years, with a minimum of 12 years and a maximum of 80 years.
# - The average age at diagnosis (`edad_diag`) is around 34 years, with a minimum of 4 years and a maximum of 76 years.
#
# Laboratory Values:
# - Various laboratory parameters are included in this dataset, such as calprotectin, erythrocyte sedimentation rate, sodium, glucose, and more. Since these values are not normalized, comparing them directly is not feasible. This limitation hinders the exploration of metrics such as variable standard deviation, making it difficult to identify which variable exhibits a higher standard deviation. It is highly recommended to perform z-score normalization beforehand to address this issue.

# %% [markdown]
# Factors analysis will be performed

# %%
display(excel_df.describe(include='category').transpose())
# Out:
#                                       count unique          top   freq
# ppio_activo                             228      2  USTEKINUMAB    136
# sexo                                    228      2            M    120
# familia_eii                           223.0    3.0          0.0  192.0
# loc_ec                                  228      6            1     78
# comp_ec                                 228      4            1     76
# exten_cu                                228      4            0    170
# tipo_eii                                228      2           EC    170
# preianal                                228      2            0    136
# ada_previo                              228      2            1    128
# ifx_previo                              228      2            1    140
# uste_previo                             228      2            0    226
# vedo_previo                             228      2            0    206
# tofa_previo                             228      2            0    224
# certol_previo                           228      2            0    220
# golim_previo                            228      2            0    224
# cx_previa_eii                           228      2            0    175
# tabaco                                226.0    3.0          0.0  129.0
# meis_espondiloartropatías               228      2            0    191
# meis_uveitis                            228      2            0    221
# meis_eritema_nodoso                     228      2            0    222
# meis_pioderma_gangrenoso                228      2            0    227
# meis_colangitis_esclerosanteprimaria    228      2            0    226
# meis_estomatitis_aftosa                 228      2            0    224
# meis_SdSweet                            228      2            0    226
# meis_psoriasis                          228      2            0    211
# meis_hidrosiadenitis                    228      2            0    225
# meis_vasculitis                         228      2            0    226
# meis_vitiligo                           228      2            0    227
# meis_osteoporosis                       228      2            0    196
# meis_fenom_tromboembolico               228      2            0    217
# res_clin_26                             228      2            1    179
# res_clin_52                             228      3            1    183
# rem_clin_52                             228      3            1    124
# res_clin_104                            190      3            1    126
# rem_clin_104                            190      3            1     95
# cort_12m_previo                         228      2            1    136
# diabetes                                227      2           no    208
# asma                                    227      2           no    202
# vih                                     227      2           no    225
# migrana                                 227      2           no    206

# %% [markdown]
# Ensure that the values for levels are encoded as integers instead of floats.

# %%
excel_df["familia_eii"] = excel_df["familia_eii"].astype("Int64").astype("category")
excel_df["tabaco"] = excel_df["tabaco"].astype("Int64").astype("category")

encoder_dict = {'no': 0, 'si': 1}
excel_df["diabetes"] = excel_df["diabetes"].replace(encoder_dict)
excel_df["asma"] = excel_df["asma"].replace(encoder_dict)
excel_df["vih"] = excel_df["vih"].replace(encoder_dict)
excel_df["migrana"] = excel_df["migrana"].replace(encoder_dict)

display(excel_df.describe(include='category').transpose())
# Out:
#                                      count unique          top freq
# ppio_activo                            228      2  USTEKINUMAB  136
# sexo                                   228      2            M  120
# familia_eii                            223      3            0  192
# loc_ec                                 228      6            1   78
# comp_ec                                228      4            1   76
# exten_cu                               228      4            0  170
# tipo_eii                               228      2           EC  170
# preianal                               228      2            0  136
# ada_previo                             228      2            1  128
# ifx_previo                             228      2            1  140
# uste_previo                            228      2            0  226
# vedo_previo                            228      2            0  206
# tofa_previo                            228      2            0  224
# certol_previo                          228      2            0  220
# golim_previo                           228      2            0  224
# cx_previa_eii                          228      2            0  175
# tabaco                                 226      3            0  129
# meis_espondiloartropatías              228      2            0  191
# meis_uveitis                           228      2            0  221
# meis_eritema_nodoso                    228      2            0  222
# meis_pioderma_gangrenoso               228      2            0  227
# meis_colangitis_esclerosanteprimaria   228      2            0  226
# meis_estomatitis_aftosa                228      2            0  224
# meis_SdSweet                           228      2            0  226
# meis_psoriasis                         228      2            0  211
# meis_hidrosiadenitis                   228      2            0  225
# meis_vasculitis                        228      2            0  226
# meis_vitiligo                          228      2            0  227
# meis_osteoporosis                      228      2            0  196
# meis_fenom_tromboembolico              228      2            0  217
# res_clin_26                            228      2            1  179
# res_clin_52                            228      3            1  183
# rem_clin_52                            228      3            1  124
# res_clin_104                           190      3            1  126
# rem_clin_104                           190      3            1   95
# cort_12m_previo                        228      2            1  136
# diabetes                               227      2            0  208
# asma                                   227      2            0  202
# vih                                    227      2            0  225
# migrana                                227      2            0  206

# %% [markdown]
# ## 7. Save the df
# The dataframe will be saved as a Python object to load it with the correct dtypes and faster.

# %%
with open("./data/df_clean.pkl", "wb") as file:
    pickle.dump(excel_df, file)

excel_df.to_csv('./data/clean_df.csv', index=True)
